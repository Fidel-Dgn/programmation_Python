# %% [markdown]
# # TP2 : Introduction à l'algorithmique et à Python
#
# ## NOM ETUDIANT : (à compléter)
#
# ## Manipualtion de structures de type array
#
#
# Chaque notebook de TP est à déposer sur moodle dans la zone de dépôt dédiée, au plus tard, la semaine suivant le TP.
# Ce dépôt tient lieu de compte-rendu et sera évalué.
#
# Le nom de votre fichier .ipynb doit contenir votre nom. Exemple : TP1_PYTHON_2024_DUPONT.ipynb
#
# ### Bonnes pratiques :
#      - les noms de variables et de constantes doivent être explicites sauf s'il existe des conventions                        par exemple i,j,k pour les indices ;
#      - le code doit être commenté lorsque les actions réalisées sont complexes
#          les commentaires doivent refléter l'algorithme sous-jacent ;
#      - chaque programme doit faire l'objet des tests des cas limite et d'un rapport de tests
#          tester le fonctionnement normal, ainsi que les cas d'erreur potentiels.
#
# Le code est écrit dans une cellule code et les rapports de tests par copie-coller des résultats des tests successifs,  et ce, en dessous du texte de l'exercice.
#
# Un rapport de test s'accompagne de message explicitant la demande de saise ou bien la nature de la valeur affichée. On doit comprendre la nature du test effectué.
#
# Par exemple
#
# Saisir une valeur
# Valeur lue = 8
# Valeur binarisée = 0
#
# Ceci notebook tient lieu de compte-rendu de TP.Faire une version html (File > Save and Export Notebook as > choix html)
#
# RENDU :
# Renommer votre notebbok en incluant votre NOM --> TP1_PYTHON_ETUD_VOTRE_NOM.ipynb
# Faire une version html (File > Save and Export Notebook as > choix html) du notebook (cela permet de visialiser rapidement le travail effectivement réalisé)
# Faire une archive avec la version ipynb et la version html
# Déposer l'archive sur moodle dans la zonne de dépôt dédiée.

# %%
#  A NOTER 
# les commandes UNIX à exécuter depuis un notebook doivent être précédées de !
# pour que le changement de répertoire soit effectif la commande cd doit être précédée de %

# vérifier où on se trouve dans l'arborescence des fichiers ... quelques commandes UNIX de base
# !pwd; ls;
#!mkdir TP1_VOTRE_NOM
#%cd chemin_vers_le_répertoire
#!pwd; ls; 

# marque un commentaire

# %% [markdown]
# ### EXERCICE 1 : Type structuré : tableau à 2 dimensions avec le type array de numpy
#
# Une image en noir et blanc est une matrice (tableau à 2 dimensions) dont les valeurs sont soit 0 pour NOIR soit 255 pour BLANC (et non 1 comme dans le TP1).
#
# Pour pouvoir travailler avec une image il faut d'abord la charger (lire le fichier au format image .bmp, .jpg, ...
# puis la copier dans un tableau de type array. C'est ce qui est utilisé ici mais il y a d'autres possibilités que vous verrez plus tard.
#
# #### Exercice 1.1
# 1) Étudier le code suivant = Lire et Comprendre la logique du code et ce qu'il est censé faire
# 2) Adapter le code pour traiter les images que vous avez récupérées (dossier TEST_TP_PYTHON)
# 3) Exécuter le code, vérifier que le résultat correspond à ce que vous aviez compris
# 4) Tester plusieurs images
# 5) Garder les traces de vos tests les plus significatifs dans une zone de texte (markdown)

# %%
## Exercice 1.1

# bibliothèque à importer

import numpy as np                        # pour la gestion des tableaux de type array
import matplotlib as mpl                  # pour travailler avec tout type de figures
import matplotlib.pyplot as plt           # pour tracer des figures      

# mémorisation du chemin vers le dossier contenant les données à traiter
PATH = 'C:/Users/Etudiant/Documents/fidel/Projet/programmation_Python/ETUD_TP2_SUJETS/TEST_TP_PYTHON'

# chargement d'une image donnée noir et blanc - résultant d'une binarisation
# utilisation des fonctionnalités de la bibliothèque MATPLOTLIB
# résultat directement en np.array

mon_image_nb = mpl.image.imread(PATH + '/63.bmp')
# affichage de la matrice directement dans la trace
print(type(mon_image_nb), '\n')    
print(mon_image_nb)

# calcul des valeurs des dimensions de l'image lue
hauteur, largeur = mon_image_nb.shape
# Valeurs des 2 dimensions récupérées
print('Taille de l\'image = ', hauteur, ' x ', largeur, '\n')  

# type du tableau et des éléments du tableau
print('type élément = ', type(mon_image_nb[0][0]), '\n')

# affichage de la matrice comme une image en niveaux de grix
plt.imshow(mon_image_nb, cmap='gray')
# Out:
# <class 'numpy.ndarray'>
#
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]
# Taille de l'image =  136  x  150
#
# type élément =  <class 'numpy.uint8'>

# %% [markdown]
# <class 'numpy.ndarray'>
#
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]
# Taille de l'image =  140  x  148
#
# type élément =  <class 'numpy.uint8'>
#
# <matplotlib.image.AxesImage at 0x211e5a2f890>
#
#
#
# ![image.png](attachment:image.png)
#
#
#
#
# <class 'numpy.ndarray'>
#
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]
# Taille de l'image =  88  x  211
#
# type élément =  <class 'numpy.uint8'>
#
# <matplotlib.image.AxesImage at 0x211e38f1090>
#
#
# ![image-2.png](attachment:image-2.png)
#
#
#
# <class 'numpy.ndarray'>
#
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]
# Taille de l'image =  120  x  128
#
# type élément =  <class 'numpy.uint8'>
#
# <matplotlib.image.AxesImage at 0x211e3937250>
#
#
# ![image-3.png](attachment:image-3.png)
#
#
#
# <class 'numpy.ndarray'>
#
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]
# Taille de l'image =  136  x  150
#
# type élément =  <class 'numpy.uint8'>
#
# <matplotlib.image.AxesImage at 0x211e39c5090>
#
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# #### Exercice 1.2 : parcours d'un tableau à 2 dimensions
#
# Effectuez les transformations suivantes.
#
# Dans des cellules de code séparées :
#
# 1) créer image_negatif en inversant les valeurs 0 <--> 255 et afficher l'image pour vérifier ainsi que le nombre de pixel noir et blanc après transformation
#
# 2) créer une image en changeant la couleur de fond (blanc) par un niveau de gris. Contrôler la validité de la valeur lue avant d'effectuer le traitement. Sortir au bout de 3 essais sinon. Conserver la valeur BLANC sur tout le pourtour de la figure.
#
# 3) Pour chaque transformation, vous créerez une copie de l'image d'origine lue et vous vérifierez que l'identifiant de la copie est bien différent de celui de l'original et vous afficherez les dimension de l'image traitée.

# %%
# Exercice 1.2 - Image en négatif
image_negatif=mon_image_nb.copy()
if(id(image_negatif)!=id(mon_image_nb)):
    print("image_negatif est une copie de mon_image_nb\n")
    for i in range(hauteur):
        for j in range(largeur):
            if image_negatif[i][j] == 0:
                image_negatif[i][j] = 255
            else:
                image_negatif[i][j] = 0
    nb_pixels_noir = np.sum(image_negatif == 0)
    nb_pixels_blanc = np.sum(image_negatif == 255)
    print('Nombre de pixels noirs = ', nb_pixels_noir, '\n')
    print('Nombre de pixels blancs = ', nb_pixels_blanc, '\n')
    print("id_mon_image_nb:", id(mon_image_nb), '\n')
    print("id_image_negatif:", id(image_negatif), '\n')
    print('Taille de l\'image = ', image_negatif.shape[0], ' x ', image_negatif.shape[1], '\n')

    plt.imshow(image_negatif, cmap='gray')
# Out:
# image_negatif est une copie de mon_image_nb
#
# Nombre de pixels noirs =  15130
#
# Nombre de pixels blancs =  5270
#
# id_mon_image_nb: 1432997482192
#
# id_image_negatif: 1432998553488
#
# Taille de l'image =  136  x  150

# %% [markdown]
# image_negatif est une copie de mon_image_nb
#
# Nombre de pixels noirs =  15130
#
# Nombre de pixels blancs =  5270
#
# id_mon_image_nb: 1432997482192
#
# id_image_negatif: 1432998553488
#
# Taille de l'image =  136  x  150
#
#
# <matplotlib.image.AxesImage at 0x211e5d0e0d0>
#
#
# ![image.png](attachment:image.png)

# %%
# Exercice 1.2 - Image avec changement de fond
image_fond=mon_image_nb.copy()
if(id(image_fond)!=id(mon_image_nb)):
    print("image_fond est une copie de mon_image_nb\n")
    tentative = 0
    b=True
    while tentative < 3 and b:  # Par exemple, on limite à 10 tentatives
        valeur_fond_gris = int(input("Entrez la valeur de fond en niveaux de gris (0-255) : "))
        if 0 <= valeur_fond_gris <= 255:
            b = False
        else:
            print("Valeur invalide. Veuillez entrer une valeur entre 0 et 255.")
            tentative += 1
    if tentative == 3:
        print("Nombre maximum de tentatives atteint. ")
    else:
        print("Valeur de fond acceptée... ", valeur_fond_gris)
        image_fond[image_fond == 255] = valeur_fond_gris
        for i in range(hauteur):
            for j in range(largeur):
                if i==0 or i==hauteur-1 or j==0 or j==largeur-1:
                    image_fond[i][j] = 255
                    
    print('Taille de l\'image = ', image_fond.shape[0], ' x ', image_fond.shape[1], '\n')

    print("id_image_fond:", id(mon_image_nb), '\n')   

    print("id_image_fond:", id(image_fond), '\n')              
    plt.imshow(image_fond, cmap='gray')
# Out:
# image_fond est une copie de mon_image_nb
#
# Valeur de fond acceptée...  150
# Taille de l'image =  136  x  150
#
# id_image_fond: 1432997482192
#
# id_image_fond: 1432998683024

# %% [markdown]
# image_fond est une copie de mon_image_nb
#
# Valeur de fond acceptée...  150
# Taille de l'image =  136  x  150
#
# id_image_fond: 1432997482192
#
# id_image_fond: 1432998683024
#
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Exercice 2 : image et boite englobante
#
# A partir de l'image noir et blanc initiale, tracer un cadre en gris autour de l'objet en noir.
#
# Méthode : Pour avoir la boite englobante d'un objet détecté il faut avoir le coin supérieur gauche et le coin inférieur droit.
# Prendre une marge de DELTA pixels (à gauche et à droite, en haut et en bas, pour que le cadre ne colle pas à l'objet.
#
# Vérifier que c'est possible (on ne décalle pas si c'est trop près du bord de l'image).
#
# Vous définirez la valeur de DELTA en réalisant plusieurs tentatives de façon à ce que le cadre ne soit ni trop large ni trop étroit (ne doit pas toucher le bord de l'objet)
#
# Appliquer le programme à plusieurs images et sauvegarder l'image générée (avec le cadre) dans le dossier OBJET_DETECTES que vous aurez créé à cet effet dans le dossier dédié à ce TP.
#
# Pour cela utiliser la séquence de code suivante
#
#     plt.figure()
#
#     plt.imshow(Image_avec_boite_englobante, cmap='gray')
#
#     plt.savefig(Chemin_vers_votre_dossier + 'Nom_fichier_a_creer.jpg')
#
# avec Chemin_vers_votre_dossier = '/home/..../OBJETS_DETECTES/'

# %%
### EXERCICE 2 : Manipulation de tableau à 2 dimensions  


# Sauvergarde de la nouvelle image incluant la boite englobante
PATH_SAUVEGARDE = 'C:/Users/Etudiant/Documents/fidel/Projet/programmation_Python/ETUD_TP2_SUJETS/OBJECT_DETECTE' 


for i in range(51, 64):
    mon_image = mpl.image.imread(PATH + f'/{i}.bmp')
    
    # Compléter le code
    img_boite_englobante = mon_image.copy()
    delta=10  # Définir la valeur de delta selon vos besoins
    Gray_value = 128  # Valeur de gris pour le fond
    ligne_noire, colonne_noire = np.where(img_boite_englobante == 0)

    print("Lignes des pixels noirs : ", ligne_noire)
    print("Colonnes des pixels noirs : ", colonne_noire)
    if (len(ligne_noire)==0) or (len(colonne_noire)==0):
        print("Aucun objet détecté donc pas de boîte englobante trouvée.")
    else:
        ligne_min = np.min(ligne_noire)
        ligne_max = np.max(ligne_noire)
        colonne_min = np.min(colonne_noire)
        colonne_max = np.max(colonne_noire)

    # Ajuster les coordonnées de la boîte englobante avec delta
        ligne_min_ajust = max(ligne_min - delta, 0)
        ligne_max_ajust = min(ligne_max + delta, img_boite_englobante.shape[0] - 1)
        colonne_min_ajust = max(colonne_min - delta, 0)
        colonne_max_ajust = min(colonne_max + delta, img_boite_englobante.shape[1] - 1)

    #trace des lignes de la boîte englobante sur l'image
        img_boite_englobante[ligne_min_ajust:ligne_max_ajust+1, colonne_min_ajust] = Gray_value  # Ligne gauche
        img_boite_englobante[ligne_min_ajust:ligne_max_ajust+1, colonne_max_ajust] = Gray_value  # Ligne droite
        img_boite_englobante[ligne_min_ajust, colonne_min_ajust:colonne_max_ajust+1] = Gray_value  # Ligne haut
        img_boite_englobante[ligne_max_ajust, colonne_min_ajust:colonne_max_ajust+1] = Gray_value  # Ligne bas
        

    

    plt.figure()
    plt.imshow(img_boite_englobante, cmap='gray')  
    plt.savefig(PATH_SAUVEGARDE + f'/image{i}.jpg')
# Out:
# Lignes des pixels noirs :  [ 49  49  49  49  49  49  50  50  50  50  50  50  50  50  50  51  51  51
#   51  51  51  51  51  51  51  51  52  52  52  52  52  52  52  52  52  52
#   52  52  53  53  53  53  53  53  53  53  53  53  54  54  54  54  54  54
#   54  54  54  54  55  55  55  55  55  55  55  55  55  55  56  56  56  56
#   56  56  56  56  57  57  57  57  57  57  57  57  58  58  58  58  58  58
#   58  58  59  59  59  59  59  59  59  59  59  59  59  60  60  60  60  60
#   60  60  60  60  60  60  60  60  60  60  60  60  61  61  61  61  61  61
#   61  61  61  61  61  61  61  61  61  61  61  61  61  61  61  61  61  61
#   61  61  62  62  62  62  62  62  62  62  62  62  62  62  62  62  62  62
#   62  62  62  62  62  62  62  62  62  62  62  63  63  63  63  63  63  63
#   63  63  63  63  63  63  63  63  63  63  63  63  63  63  63  63  63  63
#   63  63  63  63  63  64  64  64  64  64  64  64  64  64  64  64  64  64
# ...

# %%
# Vérifier la création de l'image
# !pwd; ls
